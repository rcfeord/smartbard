# %%
import pandas as pd

# %%
file = '../data/limerick_dataset_oedilf_v3.json'

df = pd.read_json(file)

# %%
df
# Out:
#                  author                                           limerick  \
# 0      Chris J. Strolin  The very first word here is a.\nIt's used with...
# 1               BobHale  "I'm really hon'rably intentioned,"\nHe said t...
# 2       Richard English  If a bovine in some leafy glade\nShould swallo...
# 3            Tim Alborn  The ham-handed chef at IHOP\nLost his grip, an...
# 4                 Virge  Our abode, dear (that place with the smell),\n...
# ...                 ...                                                ...
# 98449  Giorgio Coniglio  We scholars in wordplay well-versed\nDream up ...
# 98450  Giorgio Coniglio  The false positive rate of a test:\nCrucial fa...
# 98451  Giorgio Coniglio  A self-proclaimed math maven, Steven,\nHad fol...
# 98452  Giorgio Coniglio  Seafood fans adore "peel 'em and eat 'em".\nWi...
# 98453  Giorgio Coniglio  From plush banquets to BYOB,\nAnd from potlatc...
#
#            id  is_limerick
# 0           1        False
# ...

# %%
data = df[df['is_limerick'] == True]
data
# Out:
#                  author                                           limerick  \
# 2       Richard English  If a bovine in some leafy glade\nShould swallo...
# 4                 Virge  Our abode, dear (that place with the smell),\n...
# 6                 Virge  Quoth the office wall icon, "Achieve!\nYou can...
# 8            Meg Beagle  Our tomatoes this year are abounding;\nThey're...
# 10           Meg Beagle  I'm not one of you limerick chums,\nAnd the th...
# ...                 ...                                                ...
# 98444          Dr. Work  Fire fountains may sound pretty cool,\nBut don...
# 98446       MattMonitto  As a gent of the uppermost class,\nI'm deservi...
# 98447       entcinnamon  Breaking free, the crook busted the link\nOf t...
# 98448  Giorgio Coniglio  Mr. Owl ate Ms. Nan's metal worm —\nTragic fab...
# 98450  Giorgio Coniglio  The false positive rate of a test:\nCrucial fa...
#
#            id  is_limerick
# 2           3         True
# ...

# %%
print(data.iloc[11,1])
# Out:
# Aladdin was surely depraved.
# I was plucked from my lamp and enslaved.
# The despotic young thug
# Sought to fly on a rug.
# You'd think he'd be better behaved.
